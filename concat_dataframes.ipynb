# %%
import pandas as pd
import matplotlib.pyplot as plt

m2 = pd.read_csv("/Users/arsenpankiv/Desktop/Python_practice/merge1.csv")
m1 = pd.read_csv("/Users/arsenpankiv/Desktop/Python_practice/merge2.csv")

# %%
m2
# Out:
#                    area  crime_rate  population_density  total_businesses  \
# 0        city of london        12.5              8923.0              1450
# 1  barking and dagenham        15.2             18567.0              1380
# 2                 brent         8.7             35678.0              3450
# 3                bexley         9.1             24876.0              1950
# 4                 brent        11.3             29543.0              1670
# 5               bromley         7.8                 NaN              1350
# 6                camden        14.2                 NaN               980
#
#   industry_type        date
# 0       Finance  01/01/1999
# 1          Tech  01/01/1999
# 2          Tech  01/01/1999
# 3  Data Science  01/01/1999
# 4  Data Science  01/01/1999
# 5  Data Science  01/01/1999
# 6  Data Science  01/01/1999

# %%
m1
# Out:
#                    area  mean_salary  recycling_pct  population_size  \
# 0        city of london        48922              0           6581.0
# 1  barking and dagenham        23620              3         162444.0
# 2                 brent        23128              8         313469.0
# 3                bexley        21386             18         217458.0
# 4                 brent        20911              6         260317.0
# 5               bromley        21293             13              NaN
# 6                camden        30249             13              NaN
#
#    num_of_jobs               job_title        date
# 0       122000      Operations Analyst  01/02/1999
# 1       115000  Database Administrator  01/02/1999
# 2       291000  Database Administrator  01/02/1999
# 3       160000            Statistician  01/02/1999
# 4       134000            Statistician  01/02/1999
# 5       113000            Statistician  01/02/1999
# 6        84000            Statistician  01/02/1999

# %%
"""let's here do not make the dataframe wider instead let's stack one dataset on another; basically, we will apenend rows for dataframe"""

pd.concat([m1,m2])

"""we may also ingnore index"""
pd.concat([m1,m2], ignore_index=True)
# Out:
#                     area  mean_salary  recycling_pct  population_size  \
# 0         city of london      48922.0            0.0           6581.0
# 1   barking and dagenham      23620.0            3.0         162444.0
# 2                  brent      23128.0            8.0         313469.0
# 3                 bexley      21386.0           18.0         217458.0
# 4                  brent      20911.0            6.0         260317.0
# 5                bromley      21293.0           13.0              NaN
# 6                 camden      30249.0           13.0              NaN
# 7         city of london          NaN            NaN              NaN
# 8   barking and dagenham          NaN            NaN              NaN
# 9                  brent          NaN            NaN              NaN
# 10                bexley          NaN            NaN              NaN
# 11                 brent          NaN            NaN              NaN
# ...
