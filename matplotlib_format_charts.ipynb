# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import ast

# Load data
rf = pd.read_csv("/Users/arsenpankiv/Desktop/Python_practice/small_dataset.csv")

# Clean data
rf["date"] = pd.to_datetime(rf["date"])
rf["skills_list"] = rf["skills_list"].apply(
    lambda skills: ast.literal_eval(skills) if isinstance(skills, str) else skills
)

# %%
# ab, ac = plt.subplots()
# ab, ac = plt.subplots(2,3)
rf["job_title"].value_counts()
# Out:
# job_title
# Statistician              11
# Database Administrator     8
# Operations Analyst         7
# Name: count, dtype: int64

# %%
rf["area"].value_counts().head(5)
# Out:
# area
# brent             4
# city of london    2
# inner london      2
# bexley            2
# great britain     2
# Name: count, dtype: int64

# %%
rf["job_title"].value_counts()

rf["area"].value_counts().head(5)

fig, ax = plt.subplots(1,2)

rf["job_title"].value_counts().plot(kind="bar", ax=ax[1])

rf["area"].value_counts().head(5).plot(kind="bar",ax=ax[0])


"""fig is an entire thing and ax is an individual graph, plot; let's now fix the layout"""

fig.tight_layout()

# %%
"""we may do it another way"""
