# %%
import pandas as pd
import matplotlib.pyplot as plt

rf = pd.read_csv("/Users/arsenpankiv/Desktop/Python_practice/small_dataset_doubled.csv")
rf["date"] = pd.to_datetime(rf["date"])

# %%
rf["month_var"] = rf["date"].dt.strftime("%b")

months = rf["month_var"].unique()
{month: month for month in months}


mn_frames = {month: rf[rf["month_var"] == month] for month in months}
mn_frames["Jan"]
concated = pd.concat([mn_frames["Jan"],mn_frames["Feb"],mn_frames["Apr"]], ignore_index=True)
concated
# Out:
#          code                  area       date  median_salary  \
# 0   E09000002  barking and dagenham 1999-01-11        21480.0
# 1   E09000009                ealing 1999-01-11        20580.0
# 2   N92000002                 brent 1999-01-03        15798.0
# 3   E09000005                 brent 1999-01-12        18532.0
# 4   E13000002          outer london 1999-02-03            NaN
# 5   E92000001               england 1999-02-11        17939.0
# 6   K04000001     england and wales 1999-02-05        17974.0
# 7   E13000001          inner london 1999-02-07            NaN
# 8   K02000001        united kingdom 1999-02-12        17803.0
# 9   K04000001     england and wales 1999-02-05        17974.0
# 10  N92000002                 brent 1999-04-03        15798.0
# 11  E09000003                 brent 1999-04-03            NaN
# 12  E09000004                bexley 1999-04-05        18621.0
#
#     life_satisfaction  mean_salary  recycling_pct  population_size  \
# ...

# %%
"""MAIN PART - let's focus on exporting this dataframe - let's explore each of them"""

concated.to_clipboard(sep=",")

"comand + V - copy and paste - we separate it by comma"

# %% [markdown]
# ,code,area,date,median_salary,life_satisfaction,mean_salary,recycling_pct,population_size,num_of_jobs,job_title,month_var
# 0,E09000002,barking and dagenham,1999-01-11,21480.0,,23620.0,3.0,162444.0,115000.0,Database Administrator,Jan
# 1,E09000009,ealing,1999-01-11,20580.0,,25046.0,12.0,302252.0,120000.0,Statistician,Jan
# 2,N92000002,brent,1999-01-03,15798.0,,19093.0,,1679006.0,140000.0,Database Administrator,Jan
# 3,E09000005,brent,1999-01-12,18532.0,,20911.0,7.0,260317.0,134000.0,Database Administrator,Jan
# 4,E13000002,outer london,1999-02-03,,,,,4403196.0,177000.0,Database Administrator,Feb
# 5,E92000001,england,1999-02-11,17939.0,,21561.0,10.0,49032872.0,146000.0,Database Administrator,Feb
# 6,K04000001,england and wales,1999-02-05,17974.0,,21549.0,,51933471.0,85000.0,Operations Analyst,Feb
# 7,E13000001,inner london,1999-02-07,,,,,2750716.0,890121.0,Statistician,Feb
# 8,K02000001,united kingdom,1999-02-12,17803.0,,21315.0,,58684427.0,,Statistician,Feb
# 9,K04000001,england and wales,1999-02-05,17974.0,,21549.0,,51933471.0,85000.0,Operations Analyst,Feb
# 10,N92000002,brent,1999-04-03,15798.0,,19093.0,,1679006.0,140000.0,Database Administrator,Apr
# 11,E09000003,brent,1999-04-03,,,23128.0,8.0,313469.0,291000.0,Database Administrator,Apr
# 12,E09000004,bexley,1999-04-05,18621.0,,21386.0,18.0,217458.0,160000.0,Statistician,Apr

# %%
# concated.to_csv("exported_dataframe.csv")
# concated.to_csv("/Users/arsenpankiv/Desktop/Python_practice/exported_dataframe1.csv")
# concated.to_excel("/Users/arsenpankiv/Desktop/Python_practice/exported_dataframe_excel.xlsx")
# concated.to_excel("exported_dataframe_excel24.xlsx")

# %%
# concated.to_pickle("pickle1.pkl")

# concated.to_parquet("parquet23.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 # concated.to_pickle("pickle1.pkl")
# ----> 3 concated.to_parquet("parquet23.parquet")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
# ...
